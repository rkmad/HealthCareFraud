# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Clean-trB-beneficiaries-df-and-three-way-merge-dfs" data-toc-modified-id="Clean-trB-beneficiaries-df-and-three-way-merge-dfs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Clean trB beneficiaries df and three way merge dfs</a></span></li><li><span><a href="#Cleaning-of-Imerge-three-way-merged-df" data-toc-modified-id="Cleaning-of-Imerge-three-way-merged-df-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cleaning of Imerge three way merged df</a></span><ul class="toc-item"><li><span><a href="#NOTE:-49-claims-are-different-wrt-ClaimDuration-and-AdmitDays" data-toc-modified-id="NOTE:-49-claims-are-different-wrt-ClaimDuration-and-AdmitDays-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>NOTE: 49 claims are different wrt ClaimDuration and AdmitDays</a></span></li></ul></li><li><span><a href="#EDA-of-Beneficiary-Demographics-Grouped-by-Provider:-Race,-Gender,-DOD" data-toc-modified-id="EDA-of-Beneficiary-Demographics-Grouped-by-Provider:-Race,-Gender,-DOD-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA of Beneficiary Demographics Grouped by Provider: Race, Gender, DOD</a></span><ul class="toc-item"><li><span><a href="#Race" data-toc-modified-id="Race-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Race</a></span></li><li><span><a href="#Sex/Gender-1-=-MALE-2-=-FEMALE" data-toc-modified-id="Sex/Gender-1-=-MALE-2-=-FEMALE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Sex/Gender 1 = MALE 2 = FEMALE</a></span></li><li><span><a href="#Fraction-Deceased" data-toc-modified-id="Fraction-Deceased-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Fraction Deceased</a></span></li></ul></li><li><span><a href="#Are-physicians-shared-between-providers?" data-toc-modified-id="Are-physicians-shared-between-providers?-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Are physicians shared between providers?</a></span><ul class="toc-item"><li><span><a href="#Attending-Physicians:-128-attending-physicians-work-at-2-or-3-providers" data-toc-modified-id="Attending-Physicians:-128-attending-physicians-work-at-2-or-3-providers-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Attending Physicians: 128 attending physicians work at 2 or 3 providers</a></span></li><li><span><a href="#operating-Physicians:-63-work-at-2-providers" data-toc-modified-id="operating-Physicians:-63-work-at-2-providers-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>operating Physicians: 63 work at 2 providers</a></span></li><li><span><a href="#Other-Physicians:-16-work-at-2-or-3-providers" data-toc-modified-id="Other-Physicians:-16-work-at-2-or-3-providers-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Other Physicians: 16 work at 2 or 3 providers</a></span></li><li><span><a href="#Note-that-530-(of-40474-total)-physicans-change-between-Attending,-Operating-and-Other" data-toc-modified-id="Note-that-530-(of-40474-total)-physicans-change-between-Attending,-Operating-and-Other-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Note that 530 (of 40474 total) physicans change between Attending, Operating and Other</a></span></li><li><span><a href="#Number-of-physicians-that-work-at-more-than-one-provider-=-206,-of-which-only-2-change-between-Att,-Opr,-Oth" data-toc-modified-id="Number-of-physicians-that-work-at-more-than-one-provider-=-206,-of-which-only-2-change-between-Att,-Opr,-Oth-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Number of physicians that work at more than one provider = 206, of which only 2 change between Att, Opr, Oth</a></span></li><li><span><a href="#But-maybe-just-having-any-Operating-Physician-or-Other-Physician-is-associated-with-fraud-providers?" data-toc-modified-id="But-maybe-just-having-any-Operating-Physician-or-Other-Physician-is-associated-with-fraud-providers?-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>But maybe just having any Operating Physician or Other Physician is associated with fraud providers?</a></span></li><li><span><a href="#Conclusions-for-analysis-of-physicians:" data-toc-modified-id="Conclusions-for-analysis-of-physicians:-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Conclusions for analysis of physicians:</a></span></li></ul></li><li><span><a href="#Relationship-between-Fraud-and-Beneficiary-Age" data-toc-modified-id="Relationship-between-Fraud-and-Beneficiary-Age-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Relationship between Fraud and Beneficiary Age</a></span></li><li><span><a href="#Inpatient-Fraud-relationship-to-various-features:" data-toc-modified-id="Inpatient-Fraud-relationship-to-various-features:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Inpatient Fraud relationship to various features:</a></span><ul class="toc-item"><li><span><a href="#Number-of-Beneficiaries-by-provider" data-toc-modified-id="Number-of-Beneficiaries-by-provider-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Number of Beneficiaries by provider</a></span></li><li><span><a href="#Number-of-Claims-by-provider" data-toc-modified-id="Number-of-Claims-by-provider-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Number of Claims by provider</a></span></li><li><span><a href="#Reimbursement" data-toc-modified-id="Reimbursement-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Reimbursement</a></span></li><li><span><a href="#State" data-toc-modified-id="State-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>State</a></span></li><li><span><a href="#Beneficiary-Age" data-toc-modified-id="Beneficiary-Age-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Beneficiary Age</a></span></li><li><span><a href="#Beneficiary-Race" data-toc-modified-id="Beneficiary-Race-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Beneficiary Race</a></span></li><li><span><a href="#Beneficiary-Sex" data-toc-modified-id="Beneficiary-Sex-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Beneficiary Sex</a></span></li><li><span><a href="#Number-Chronic-Conditions" data-toc-modified-id="Number-Chronic-Conditions-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Number Chronic Conditions</a></span></li><li><span><a href="#Inpatient-claims-Groupby-Provider,-calculate-mean-for-'ClaimStartDt'" data-toc-modified-id="Inpatient-claims-Groupby-Provider,-calculate-mean-for-'ClaimStartDt'-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Inpatient claims Groupby Provider, calculate mean for 'ClaimStartDt'</a></span></li><li><span><a href="#Start-Date-of-Claim" data-toc-modified-id="Start-Date-of-Claim-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Start Date of Claim</a></span></li><li><span><a href="#Inpatient-claims-Groupby-Provider,-calculate-mean-for-'ClaimDuration',-'AdmitDays'" data-toc-modified-id="Inpatient-claims-Groupby-Provider,-calculate-mean-for-'ClaimDuration',-'AdmitDays'-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Inpatient claims Groupby Provider, calculate mean for 'ClaimDuration', 'AdmitDays'</a></span></li><li><span><a href="#Length-of-hospital-stay" data-toc-modified-id="Length-of-hospital-stay-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Length of hospital stay</a></span></li><li><span><a href="#Length-of-claim" data-toc-modified-id="Length-of-claim-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>Length of claim</a></span></li><li><span><a href="#Number-of-Diagnostic-Codes" data-toc-modified-id="Number-of-Diagnostic-Codes-6.14"><span class="toc-item-num">6.14&nbsp;&nbsp;</span>Number of Diagnostic Codes</a></span></li><li><span><a href="#Number-of-Procedure-Codes" data-toc-modified-id="Number-of-Procedure-Codes-6.15"><span class="toc-item-num">6.15&nbsp;&nbsp;</span>Number of Procedure Codes</a></span></li><li><span><a href="#Number-of-Physicians" data-toc-modified-id="Number-of-Physicians-6.16"><span class="toc-item-num">6.16&nbsp;&nbsp;</span>Number of Physicians</a></span></li><li><span><a href="#Number-of-Beneficiaries" data-toc-modified-id="Number-of-Beneficiaries-6.17"><span class="toc-item-num">6.17&nbsp;&nbsp;</span>Number of Beneficiaries</a></span></li></ul></li><li><span><a href="#Describe-statistics-of-Potentially-fradulent-Yes-or-No" data-toc-modified-id="Describe-statistics-of-Potentially-fradulent-Yes-or-No-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Describe statistics of Potentially fradulent Yes or No</a></span></li><li><span><a href="#Are-there-more-potential-fraud-providers-in-Inpatient-or-Outpatient-claims?" data-toc-modified-id="Are-there-more-potential-fraud-providers-in-Inpatient-or-Outpatient-claims?-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Are there more potential fraud providers in Inpatient or Outpatient claims?</a></span></li><li><span><a href="#Levene-test-for-equal-variances-and-T-test-for-means" data-toc-modified-id="Levene-test-for-equal-variances-and-T-test-for-means-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Levene test for equal variances and T-test for means</a></span><ul class="toc-item"><li><span><a href="#T-test-for-equal-means-'InscClaimAmtReimbursed'-and-'AdmitDays'" data-toc-modified-id="T-test-for-equal-means-'InscClaimAmtReimbursed'-and-'AdmitDays'-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>T test for equal means 'InscClaimAmtReimbursed' and 'AdmitDays'</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.stats.weightstats

# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
sns.set(style = "whitegrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# matplotlib params
size=15
params = {'legend.fontsize': 'large',
          'figure.figsize': (20,10),
          'axes.labelsize': size*1.6,
          'axes.titlesize': size*2,
          'xtick.labelsize': size*1.5,
          'ytick.labelsize': size*1.5,
          'axes.titlepad': 25,
          'figure.titlesize': size*2,
          'legend.fontsize': size,
            'legend.title_fontsize': size*1.1
         }

plt.rcParams.update(params)

sns.set_style("whitegrid")

# %%
# read in dataframes from binaries
trB= pd.read_pickle("../data/trB.pkl") # Train Beneficiaries 
# trO= pd.read_pickle("../data/trO.pkl") # Train Outpatient Claims
trI= pd.read_pickle("../data/trI.pkl") # Train Inpatient Claims
trF= pd.read_pickle("../data/trF.pkl") # Train Provider Fraud

# %% [markdown]
# # Clean trB beneficiaries df and three way merge dfs

# %%
# convert years to datetime
trB['DOB']= pd.to_datetime(trB['DOB'])
trB['DOD']= pd.to_datetime(trB['DOD'])

# %%
# Add age column
actual_date = pd.to_datetime('2009-12-31')
# add age column, where DOD exists subtract DOB from that, if not use DOB subtracted from end of 2009 
trB['Age'] = np.where(trB['DOD'].isnull(), (actual_date - trB['DOB']).astype('<m8[Y]'), (trB['DOD'] - trB['DOB']).astype('<m8[Y]'))

# %%
# add numChronic column, number of chronic conditions for each beneficiary
trB['numChronic']= trB.iloc[:,11:22].eq(1).sum(1)

# %%
# three way merge of Inpatient claims, drop uneeded columns and 'ClmProcedureCode_6' which is empty
Imerge = trF.merge(trI.merge(trB, on='BeneID'), on='Provider').drop(['index','index_x','index_y', 'DOB', 'ClaimID','ClmProcedureCode_6','DeductibleAmtPaid' ], axis=1)

# %% [markdown]
# # Cleaning of Imerge three way merged df

# %%
# convert potentialfraud to binary

vals = {'Yes' : 1, 'No' : 0} 
Imerge['PotentialFraud'] = Imerge['PotentialFraud'].map(vals)

# %%
# feature engineering: Add features: calculate days between ClaimStartDt-ClaimEndDt, AdmissionDt-DischargeDt
# convert to datetime
Imerge['ClaimStartDt']= pd.to_datetime(Imerge['ClaimStartDt'])
Imerge['ClaimEndDt']= pd.to_datetime(Imerge['ClaimEndDt'])
Imerge['AdmissionDt']= pd.to_datetime(Imerge['AdmissionDt'])
Imerge['DischargeDt']= pd.to_datetime(Imerge['DischargeDt'])

# days of admission and claim duration
Imerge['ClaimDuration'] =(Imerge['ClaimEndDt']- Imerge['ClaimStartDt']).dt.days
Imerge['AdmitDays'] =(Imerge['DischargeDt']- Imerge['AdmissionDt']).dt.days

# change dates to day of year
Imerge['ClaimStartDt']= Imerge['ClaimStartDt'].apply(lambda x: x.timetuple().tm_yday)
Imerge['ClaimEndDt']= Imerge['ClaimEndDt'].apply(lambda x: x.timetuple().tm_yday)
Imerge['AdmissionDt']= Imerge['AdmissionDt'].apply(lambda x: x.timetuple().tm_yday)
Imerge['DischargeDt']= Imerge['DischargeDt'].apply(lambda x: x.timetuple().tm_yday)

# %%
# Change DOD to binary
Imerge[~Imerge['DOD'].isnull()]=1
Imerge['DOD'].fillna(0, inplace = True)
Imerge['DOD']= Imerge['DOD'].astype('int64')

# %%
# Gender
Imerge['Gender'].value_counts()
# 2    23267
# 1    17207
# Name: Gender, dtype: int64

# Gender to binary 1= male, 0= female
Imerge['Gender'] = Imerge['Gender'].map({2 : 0, 1 : 1})

# %%
# Race
# 1    34126
# 2     4202
# 3     1359
# 5      787
# Name: Race, dtype: int64

# Race to binary 1= white, 0 = not white
Imerge['Race'] = Imerge['Race'].map({1 : 1, 2 : 0, 3 : 0, 5 : 0})

# %%
# sum number of diagnostic or procedure codes and add into new columns

diag=['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10']
proc=['ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5']

Imerge['numDiagCodes'] = Imerge[diag].count(1)
Imerge['numProcCodes'] = Imerge[proc].count(1)

# %%
# sum number of physicians and add into new column
phys = ['AttendingPhysician', 'OperatingPhysician', 'OtherPhysician']
Imerge['numPhysicians'] = Imerge[phys].count(1)

# %%
# Fix 'RenalDiseaseIndicator' column: '0' to 2, 'Y' to 1
trB['RenalDiseaseIndicator'] = np.where(trB['RenalDiseaseIndicator']=='0', 2, trB['RenalDiseaseIndicator'])
trB['RenalDiseaseIndicator'] = np.where(trB['RenalDiseaseIndicator']=='Y', 1, trB['RenalDiseaseIndicator'])
trB['RenalDiseaseIndicator']= trB['RenalDiseaseIndicator'].astype('int64')

# Change chronic conditions to binary
ccols=['RenalDiseaseIndicator','ChronicCond_Alzheimer','ChronicCond_Heartfailure',
       'ChronicCond_KidneyDisease','ChronicCond_Cancer','ChronicCond_ObstrPulmonary',
       'ChronicCond_Depression','ChronicCond_Diabetes','ChronicCond_IschemicHeart',
       'ChronicCond_Osteoporasis','ChronicCond_rheumatoidarthritis','ChronicCond_stroke']

Imerge[ccols] = np.where(Imerge[ccols]==2, 0, Imerge[ccols])

# %%
# Average Reimbursment per day per claim (add small constant to 'AdmitDays' to avoid divide by zero)
Imerge['ReimbPerDayAdmit']= (Imerge['InscClaimAmtReimbursed']/(Imerge['AdmitDays']+0.001)).astype('int64')

# %%
# convert columns to object type: ClmProcedureCode_1_mode, etc.

proc=['ClmProcedureCode_1',
'ClmProcedureCode_2',
'ClmProcedureCode_3', 
'ClmProcedureCode_4',
'ClmProcedureCode_5']

Imerge[proc]= Imerge[proc].astype("object")

# %% [markdown]
# ## NOTE: 49 claims are different wrt ClaimDuration and AdmitDays

# %%
 #49 claims are different wrt ClaimDuration and AdmitDays
(Imerge['ClaimDuration'] != Imerge['AdmitDays']).value_counts() #49 claims are different wrt ClaimDuration and AdmitDays
# Out:
# False    40425
# True        49
# dtype: int64

# %%
str_columns = ['Provider', 'BeneID', 'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician', 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode']+diag+proc

# %%
#Imerge.to_pickle("../data/Imerge.pkl")

# %%
Imerge= pd.read_pickle("../data/Imerge.pkl")

# %% [markdown]
# # EDA of Beneficiary Demographics Grouped by Provider: Race, Gender, DOD

# %% [markdown]
# ## Race

# %%
Imerge['Race'].value_counts()
# Out:
# 1    34126
# 0     6348
# Name: Race, dtype: int64

# %%
Imerge_race= Imerge.groupby(['Provider','PotentialFraud','Race']).size().to_frame(name='size').reset_index()

# %%
Imerge_race_pivot= Imerge_race.pivot_table(columns='Race', index=['Provider', 'PotentialFraud'],values='size')
print(Imerge_race_pivot)
# Out:
# Race                        0     1
# Provider PotentialFraud
# PRV51001 0                NaN   5.0
# PRV51003 1               13.0  49.0
# PRV51007 0                NaN   3.0
# PRV51008 0                NaN   2.0
# PRV51011 0                NaN   1.0
# ...                       ...   ...
# PRV57719 0                NaN   4.0
# PRV57728 0                NaN   1.0
# PRV57729 0                3.0   8.0
# PRV57732 0                2.0   9.0
# PRV57757 0                1.0  10.0
#
# [2092 rows x 2 columns]

# %%
Imerge_race_pivot.reset_index(inplace=True)

# %%
Imerge_race_pivot['Rsum']=Imerge_race_pivot.iloc[:,-2:].sum(1).values

# %%
Imerge_race_pivot_ratio= Imerge_race_pivot.iloc[:,[-3]].apply(lambda x: x/Imerge_race_pivot.Rsum, axis=0).reset_index()
Imerge_race_pivot_ratio.fillna(0, inplace = True)
Imerge_race_pivot_ratio = pd.concat([Imerge_race_pivot[['Provider','PotentialFraud']], Imerge_race_pivot_ratio], axis=1)

# %%
Imerge_race_pivot_ratio
# Out:
# Race  Provider  PotentialFraud  index         0
# 0     PRV51001               0      0  0.000000
# 1     PRV51003               1      1  0.209677
# 2     PRV51007               0      2  0.000000
# 3     PRV51008               0      3  0.000000
# 4     PRV51011               0      4  0.000000
# ...        ...             ...    ...       ...
# 2087  PRV57719               0   2087  0.000000
# 2088  PRV57728               0   2088  0.000000
# 2089  PRV57729               0   2089  0.272727
# 2090  PRV57732               0   2090  0.181818
# 2091  PRV57757               0   2091  0.090909
#
# [2092 rows x 4 columns]

# %%
# Fraud by Distribution by Fraction Race Non-White by provider
sns.boxplot(data=Imerge_race_pivot_ratio, x='PotentialFraud', y=Imerge_race_pivot_ratio[0])
#plt.ylim(6000,8000)
plt.title('Fraud by Distribution by Fraction Race Non-White by provider')
plt.xlabel('Potential Fraud averaged by provider')
plt.ylabel('Fraction Race Non-White')
#plt.legend()
# Out:
# Text(0, 0.5, 'Fraction Race Non-White')

# %% [markdown]
# ## Sex/Gender 1 = MALE 2 = FEMALE

# %%
Imerge['Gender'].value_counts()
# Out:
# 0    23267
# 1    17207
# Name: Gender, dtype: int64

# %%
Imerge_gender= Imerge.groupby(['Provider','PotentialFraud','Gender']).size().to_frame(name='size').reset_index()
Imerge_gender
# Out:
#       Provider  PotentialFraud  Gender  size
# 0     PRV51001               0       0     3
# 1     PRV51001               0       1     2
# 2     PRV51003               1       0    41
# 3     PRV51003               1       1    21
# 4     PRV51007               0       0     2
# ...        ...             ...     ...   ...
# 3758  PRV57729               0       1     7
# 3759  PRV57732               0       0     7
# 3760  PRV57732               0       1     4
# 3761  PRV57757               0       0     5
# 3762  PRV57757               0       1     6
#
# [3763 rows x 4 columns]

# %%
Imerge_gender_pivot= Imerge_gender.pivot_table(columns='Gender', index=['Provider', 'PotentialFraud'],values='size')
Imerge_gender_pivot
# Out:
# Gender                      0     1
# Provider PotentialFraud
# PRV51001 0                3.0   2.0
# PRV51003 1               41.0  21.0
# PRV51007 0                2.0   1.0
# PRV51008 0                1.0   1.0
# PRV51011 0                1.0   NaN
# ...                       ...   ...
# PRV57719 0                1.0   3.0
# PRV57728 0                NaN   1.0
# PRV57729 0                4.0   7.0
# PRV57732 0                7.0   4.0
# PRV57757 0                5.0   6.0
#
# [2092 rows x 2 columns]

# %%
Imerge_gender_pivot.reset_index(inplace=True)

# %%
Imerge_gender_pivot['MFgender_ratio']=(Imerge_gender_pivot[1].values/Imerge_gender_pivot[0].values)
Imerge_gender_pivot.fillna(0, inplace = True)
Imerge_gender_pivot
# Out:
# Gender  Provider  PotentialFraud     0     1  MFgender_ratio
# 0       PRV51001               0   3.0   2.0        0.666667
# 1       PRV51003               1  41.0  21.0        0.512195
# 2       PRV51007               0   2.0   1.0        0.500000
# 3       PRV51008               0   1.0   1.0        1.000000
# 4       PRV51011               0   1.0   0.0        0.000000
# ...          ...             ...   ...   ...             ...
# 2087    PRV57719               0   1.0   3.0        3.000000
# 2088    PRV57728               0   0.0   1.0        0.000000
# 2089    PRV57729               0   4.0   7.0        1.750000
# 2090    PRV57732               0   7.0   4.0        0.571429
# 2091    PRV57757               0   5.0   6.0        1.200000
#
# [2092 rows x 5 columns]

# %%
# Fraud by Distribution by Male/Female Gender Ratio by provider
sns.boxplot(data=Imerge_gender_pivot, x='PotentialFraud', y='MFgender_ratio')
#plt.ylim(6000,8000)
plt.title('Fraud by Distribution by Male/Female Gender Ratio by provider')
plt.xlabel('Potential Fraud averaged by provider')
plt.ylabel('Male/Female Gender Ratio')
#plt.legend()
# Out:
# Text(0, 0.5, 'Male/Female Gender Ratio')

# %% [markdown]
# ## Fraction Deceased

# %%
Imerge['DOD'].value_counts()
# Out:
# 0    40156
# 1      318
# Name: DOD, dtype: int64

# %%
Imerge_DOD= Imerge.groupby(['Provider','PotentialFraud','DOD']).size().to_frame(name='size').reset_index()
Imerge_DOD
# Out:
#       Provider  PotentialFraud  DOD  size
# 0     PRV51001               0    0     5
# 1     PRV51003               1    0    61
# 2     PRV51003               1    1     1
# 3     PRV51007               0    0     3
# 4     PRV51008               0    0     2
# ...        ...             ...  ...   ...
# 2318  PRV57719               0    0     4
# 2319  PRV57728               0    0     1
# 2320  PRV57729               0    0    11
# 2321  PRV57732               0    0    11
# 2322  PRV57757               0    0    11
#
# [2323 rows x 4 columns]

# %%
Imerge_DOD_pivot= Imerge_DOD.pivot_table(columns='DOD', index=['Provider', 'PotentialFraud'],values='size')
Imerge_DOD_pivot.reset_index(inplace=True)
Imerge_DOD_pivot['sum_DOD']= Imerge_DOD_pivot.iloc[:,-2:].sum(1).values

# %%
Imerge_DOD_pivot
# Out:
# DOD   Provider  PotentialFraud     0    1  sum_DOD
# 0     PRV51001               0   5.0  NaN      5.0
# 1     PRV51003               1  61.0  1.0     62.0
# 2     PRV51007               0   3.0  NaN      3.0
# 3     PRV51008               0   2.0  NaN      2.0
# 4     PRV51011               0   1.0  NaN      1.0
# ...        ...             ...   ...  ...      ...
# 2087  PRV57719               0   4.0  NaN      4.0
# 2088  PRV57728               0   1.0  NaN      1.0
# 2089  PRV57729               0  11.0  NaN     11.0
# 2090  PRV57732               0  11.0  NaN     11.0
# 2091  PRV57757               0  11.0  NaN     11.0
#
# [2092 rows x 5 columns]

# %%
Imerge_DOD_pivot.reset_index(inplace=True)

# %%
Imerge_DOD_pivot['fraction_died']=(Imerge_DOD_pivot[1].values/Imerge_DOD_pivot['sum_DOD'].values)
Imerge_DOD_pivot.fillna(0, inplace = True)
Imerge_DOD_pivot
# Out:
# DOD   index  Provider  PotentialFraud     0    1  sum_DOD  fraction_died
# 0         0  PRV51001               0   5.0  0.0      5.0       0.000000
# 1         1  PRV51003               1  61.0  1.0     62.0       0.016129
# 2         2  PRV51007               0   3.0  0.0      3.0       0.000000
# 3         3  PRV51008               0   2.0  0.0      2.0       0.000000
# 4         4  PRV51011               0   1.0  0.0      1.0       0.000000
# ...     ...       ...             ...   ...  ...      ...            ...
# 2087   2087  PRV57719               0   4.0  0.0      4.0       0.000000
# 2088   2088  PRV57728               0   1.0  0.0      1.0       0.000000
# 2089   2089  PRV57729               0  11.0  0.0     11.0       0.000000
# 2090   2090  PRV57732               0  11.0  0.0     11.0       0.000000
# 2091   2091  PRV57757               0  11.0  0.0     11.0       0.000000
#
# [2092 rows x 7 columns]

# %%
pd.set_option('display.max_rows', None)
Imerge_DOD_pivot.sort_values(by='fraction_died', ascending=False)
# Out:
# DOD   index  Provider  PotentialFraud      0    1  sum_DOD  fraction_died
# 686     686  PRV52912               0    0.0  1.0      1.0       1.000000
# 1336   1336  PRV55176               0    0.0  1.0      1.0       1.000000
# 860     860  PRV53511               0    0.0  1.0      1.0       1.000000
# 1112   1112  PRV54543               1    1.0  2.0      3.0       0.666667
# 1077   1077  PRV54384               0    1.0  1.0      2.0       0.500000
# 1553   1553  PRV55942               0    1.0  1.0      2.0       0.500000
# 1606   1606  PRV56135               0    2.0  1.0      3.0       0.333333
# 779     779  PRV53258               0    2.0  1.0      3.0       0.333333
# 126     126  PRV51311               0    2.0  1.0      3.0       0.333333
# 619     619  PRV52651               0    2.0  1.0      3.0       0.333333
# 1823   1823  PRV56775               0    2.0  1.0      3.0       0.333333
# 651     651  PRV52833               0    3.0  1.0      4.0       0.250000
# ...

# %%
# Fraud by Distribution of Fraction Diseased by provider
sns.boxplot(data=Imerge_DOD_pivot, x='PotentialFraud', y='fraction_died')
plt.ylim(0,0.205)
plt.title('Fraud by Distribution by Fraction Diseased by provider')
plt.xlabel('Potential Fraud averaged by provider')
plt.ylabel('Fraction Diseased')
#plt.legend()
# Out:
# Text(0, 0.5, 'Fraction Diseased')

# %% [markdown]
# # Are physicians shared between providers?

# %% [markdown]
# ## Attending Physicians: 128 attending physicians work at 2 or 3 providers

# %%
pd.set_option('display.max_rows', 100)
phy_drp=Imerge.groupby(['AttendingPhysician','PotentialFraud'])['Provider'].apply(pd.Series.nunique).to_frame(name='numUniqProv').reset_index()

# %%
pd.set_option('display.max_rows', None)
phy_drp_2 = phy_drp[phy_drp['numUniqProv']>1].sort_values(by='numUniqProv', ascending=False)
 # 128 attending physicians work at more than one provider

# %% [markdown]
#  ## operating Physicians: 63 work at 2 providers

# %%
phy_drp2=Imerge.groupby(['OperatingPhysician','PotentialFraud'])['Provider'].apply(pd.Series.nunique).to_frame(name='numUniqProv').reset_index()
phy_drp2_2 = phy_drp2[phy_drp2['numUniqProv']>1].sort_values(by='numUniqProv', ascending=False)

# %%
len(phy_drp2[phy_drp2['numUniqProv']>1].sort_values(by='numUniqProv', ascending=False))
# Out:
# 63

# %% [markdown]
# ## Other Physicians: 16 work at 2 or 3 providers

# %%
phy_drp3=Imerge.groupby(['OtherPhysician','PotentialFraud'])['Provider'].apply(pd.Series.nunique).to_frame(name='numUniqProv').reset_index()
phy_drp3_2=phy_drp3[phy_drp3['numUniqProv']>1].sort_values(by='numUniqProv', ascending=False)

# %%
len(phy_drp3[phy_drp3['numUniqProv']>1].sort_values(by='numUniqProv', ascending=False))
# Out:
# 16

# %% [markdown]
# ## Note that 530 (of 40474 total) physicans change between Attending, Operating and Other

# %%
att = Imerge['AttendingPhysician']
ope = Imerge['OperatingPhysician']
oth = Imerge['OtherPhysician']

# %%
len(att+ope+oth)
# Out:
# 40474

# %%
len(list(set(att) & set(ope) & set(oth)))
# Out:
# 530

# %% [markdown]
# ## Number of physicians that work at more than one provider = 206, of which only 2 change between Att, Opr, Oth
# 21% of these attending physicians are associated with fraud providers, which is same percentage overall for fraud providers 440/2092 14% of these operating physicians are associated with fraud providers 31% of these other physicians are associated with fraud provider

# %%
att_2= phy_drp_2['AttendingPhysician']
ope_2= phy_drp2_2['OperatingPhysician']
oth_2= phy_drp3_2['OtherPhysician']

phy_list_2 =np.concatenate((att_2.values,ope_2.values,oth_2.values), axis=None)

list(set(att_2) & set(ope_2) & set(oth_2))
# Out:
# ['PHY316039', 'PHY312782']

# %%
phy_list_2_att= Imerge[Imerge['AttendingPhysician'].isin(phy_list_2)]
phy_list_2_opr= Imerge[Imerge['OperatingPhysician'].isin(phy_list_2)]
phy_list_2_oth= Imerge[Imerge['OtherPhysician'].isin(phy_list_2)]

# %%
phy_list_2_att_fraud= phy_list_2_att.groupby(['Provider', 'PotentialFraud']).size().reset_index()

# %%
print(phy_list_2_att_fraud['PotentialFraud'].sum(0))
print(len(phy_list_2_att_fraud['PotentialFraud'])) # 39 potentially fraud out of 190 = 21%
# Out:
# 39
# 190

# %%
39/190 # 21%
# Out:
# 0.20526315789473684

# %%
440/2092 # 21% of inpatient providers are fraud
# Out:
# 0.21032504780114722

# %%
phy_list_2_opr_fraud= phy_list_2_opr.groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(phy_list_2_opr_fraud['PotentialFraud'].sum(0))
print(len(phy_list_2_opr_fraud['PotentialFraud'])) # 17 potentially fraud out of 125 = 13.6%
# Out:
# 17
# 125

# %%
17/125
# Out:
# 0.136

# %%
phy_list_2_oth_fraud= phy_list_2_oth.groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(phy_list_2_oth_fraud['PotentialFraud'].sum(0))
print(len(phy_list_2_oth_fraud['PotentialFraud'])) # 16 potentially fraud out of 51 = 31%
# Out:
# 16
# 51

# %%
16/51
# Out:
# 0.3137254901960784

# %%
# 16 other physicians
phy_list_2_oth
# It turns out that there is one large fraudulent provider PRV52019 that always uses a particular Other physician PHY416093, thus inflating the percentage of fraudulent other physicians

# %% [markdown]
# ## But maybe just having any Operating Physician or Other Physician is associated with fraud providers?
# ! not so, 21-22% of providers from claims having any of the three physician types are fraudulent, same frequency as overall !!

# %%
print(Imerge[Imerge['AttendingPhysician'].astype('str')!= 'None']) #40362 claims have an attending physician
att_phy_fraud = Imerge[Imerge['AttendingPhysician'].astype('str')!= 'None'].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(att_phy_fraud['PotentialFraud'].sum(0))
print(len(att_phy_fraud['PotentialFraud'])) # 440 potentially fraud out of 2089 = 21%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(Imerge[Imerge['OperatingPhysician'].astype('str')!= 'None']) #23830 claims have an operating physician
opr_phy_fraud = Imerge[Imerge['OperatingPhysician'].astype('str')!= 'None'].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(opr_phy_fraud['PotentialFraud'].sum(0))
print(len(opr_phy_fraud['PotentialFraud'])) # 439 potentially fraud out of 1959 = 22%

# %%
# Imerge[Imerge['OtherPhysician'].astype('str')!= 'None'] #4690 claims have an other physician
oth_phy_fraud = Imerge[Imerge['OtherPhysician'].astype('str')!= 'None'].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(oth_phy_fraud['PotentialFraud'].sum(0))
print(len(oth_phy_fraud['PotentialFraud'])) # 279 potentially fraud out of 1157 = 24%

# %% [markdown]
# ## Conclusions for analysis of physicians:
# For physicians that work at more than one clinic:
#
# 21% of these attending physicians are associated with fraud providers, which is same percentage overall for fraud providers 440/2092
# 14% of these operating physicians are associated with fraud providers
# 31% of these other physicians are associated with fraud providers
# BUT, it turns out that there is one large fraudulent provider PRV52019 that always uses a particular Other physician PHY416093, thus inflating the percentage of fraudulent other physicians, thus there is likely no clear correlation between physicians and fraud

# %% [markdown]
# # Relationship between Fraud and Beneficiary Age

# %%
sns.histplot(data=Imerge['Age'], bins=75)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=Imerge[Imerge['PotentialFraud']==1]['Age'], bins=75)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
# percent fraud for ages <31
age30=Imerge[(Imerge['Age']<31)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age30['PotentialFraud'].sum(0))
print(len(age30['PotentialFraud']))
print(age30['PotentialFraud'].sum(0)/len(age30['PotentialFraud'])) # 44% fraud
# Out:
# 97
# 217
# 0.4470046082949309

# %%
# percent fraud for ages 31-40
age3140=Imerge[(Imerge['Age']>30) & (Imerge['Age']<=40)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age3140['PotentialFraud'].sum(0))
print(len(age3140['PotentialFraud']))
print(age3140['PotentialFraud'].sum(0)/len(age3140['PotentialFraud'])) # 42% fraud

# %%
# percent fraud for ages 41-50
age4150=Imerge[(Imerge['Age']>40) & (Imerge['Age']<=50)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age4150['PotentialFraud'].sum(0))
print(len(age4150['PotentialFraud']))
print(age4150['PotentialFraud'].sum(0)/len(age4150['PotentialFraud'])) # 38% fraud

# %%
# percent fraud for ages 51-60
age5160=Imerge[(Imerge['Age']>50) & (Imerge['Age']<=60)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age5160['PotentialFraud'].sum(0))
print(len(age5160['PotentialFraud']))
print(age5160['PotentialFraud'].sum(0)/len(age5160['PotentialFraud'])) # 34% fraud

# %%
# percent fraud for ages 61-70
age6170=Imerge[(Imerge['Age']>60) & (Imerge['Age']<=70)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age6170['PotentialFraud'].sum(0))
print(len(age6170['PotentialFraud']))
print(age6170['PotentialFraud'].sum(0)/len(age6170['PotentialFraud'])) # 26% fraud

# %%
# percent fraud for ages 71-80
age7180=Imerge[(Imerge['Age']>70) & (Imerge['Age']<=80)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age7180['PotentialFraud'].sum(0))
print(len(age7180['PotentialFraud']))
print(age7180['PotentialFraud'].sum(0)/len(age7180['PotentialFraud'])) # 25% fraud

# %%
# percent fraud for ages 81-90
age8190=Imerge[(Imerge['Age']>80) & (Imerge['Age']<=90)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age8190['PotentialFraud'].sum(0))
print(len(age8190['PotentialFraud']))
print(age8190['PotentialFraud'].sum(0)/len(age8190['PotentialFraud'])) # 25% fraud

# %%
# percent fraud for ages 91-100
age91100=Imerge[(Imerge['Age']>91) & (Imerge['Age']<=100)].groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age91100['PotentialFraud'].sum(0))
print(len(age91100['PotentialFraud']))
print(age91100['PotentialFraud'].sum(0)/len(age91100['PotentialFraud'])) # 35% fraud

# %%
age_all=Imerge.groupby(['Provider', 'PotentialFraud']).size().reset_index()
print(age_all['PotentialFraud'].sum(0))
print(len(age_all['PotentialFraud']))
print(age_all['PotentialFraud'].sum(0)/len(age_all['PotentialFraud'])) # 21% fraud

# %%
all_age_F=Imerge[Imerge['PotentialFraud']==1].groupby(['Provider', 'PotentialFraud'])['Age'].mean().reset_index()

# %%
all_age_F['Age'].mean()

# %%
all_age=Imerge[Imerge['PotentialFraud']==0].groupby(['Provider', 'PotentialFraud'])['Age'].mean().reset_index()
all_age['Age'].mean()

# %% [markdown]
# # Inpatient Fraud relationship to various features:

# %% [markdown]
# ## Number of Beneficiaries by provider

# %%
len(Imerge[Imerge['PotentialFraud']== 'No']['Provider'].unique())
# 23403 claims ['PotentialFraud']== 'Yes'
# 17072 claims ['PotentialFraud']== 'No'
# 40474 claims total



# 440 unique providers ['PotentialFraud']== 'Yes' (of 506 Potential fraudulent providers in Fraud df)
# 1652 unique providers ['PotentialFraud']== 'No'
# 2092 unique providers total
# Out:
# 1652

# %%
Imerge
# Out:
#        Provider  PotentialFraud      BeneID  ClaimStartDt  ClaimEndDt  \
# 0      PRV51001               0   BENE36012           185         189
# 1      PRV51001               0   BENE38773           143         145
# 2      PRV51001               0   BENE98831            34          39
# 3      PRV51001               0  BENE102690           124         138
# 4      PRV51001               0  BENE152088            37          37
# ...         ...             ...         ...           ...         ...
# 40469  PRV57757               0  BENE108243            63          85
# 40470  PRV57757               0  BENE114916            43          49
# 40471  PRV57757               0  BENE123698            49          52
# 40472  PRV57757               0  BENE139580           144         145
# 40473  PRV57757               0  BENE140375           312         327
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# ...

# %%
Imerge_bene= Imerge.groupby(['Provider','PotentialFraud'])['BeneID'].apply(pd.Series.nunique).to_frame(name='beneUnique').reset_index()

# %%
Imerge_bene
# Out:
#       Provider  PotentialFraud  beneUnique
# 0     PRV51001               0           5
# 1     PRV51003               1          53
# 2     PRV51007               0           3
# 3     PRV51008               0           2
# 4     PRV51011               0           1
# ...        ...             ...         ...
# 2087  PRV57719               0           4
# 2088  PRV57728               0           1
# 2089  PRV57729               0          10
# 2090  PRV57732               0          11
# 2091  PRV57757               0          11
#
# [2092 rows x 3 columns]

# %%
# Fraud relationship to numBene averaged by provider
sns.boxplot(data=Imerge_bene, x='PotentialFraud',y='beneUnique')
#plt.ylim(6000,8000)
plt.title('Fraud by Distribution by Number of Beneficiaries averaged by provider')
plt.xlabel('Potential Fraud averaged by provider')
plt.ylabel('Number of Beneficiaries')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Beneficiaries')

# %% [markdown]
# ## Number of Claims by provider

# %%
Imerge_claims= Imerge.groupby(['Provider','PotentialFraud']).size().to_frame(name='size').reset_index()

# %%
# Fraud relationship to numClaim averaged by provider
sns.boxplot(data=Imerge_claims, x='PotentialFraud',y='size')
#plt.ylim(6000,8000)
plt.title('Fraud by Distribution by Number of Claims averaged by provider')
plt.xlabel('Potential Fraud averaged by provider')
plt.ylabel('Number of Claims')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Claims')

# %% [markdown]
# ## Reimbursement

# %%
# # Inpatient claims Groupby provider, average reimbursment
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['InscClaimAmtReimbursed']].mean().reset_index()

# %%
# Fraud relationship to Reimbursement
# sns.histplot(x=Imerge[Imerge['PotentialFraud']== 'Yes']['InscClaimAmtReimbursed'], color='red', label='Potential Fraud', bins=50)
# sns.histplot(x=Imerge[Imerge['PotentialFraud']== 'No']['InscClaimAmtReimbursed'], color='skyblue', label='Not Fraud', bins=50)

plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['InscClaimAmtReimbursed'], Imerge[Imerge['PotentialFraud']== 'No']['InscClaimAmtReimbursed']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=60)
plt.title('Fraud by Distribution of Reimbursements')
plt.xlabel('Reimbursement Amount (USD)')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Reinbursement
sns.boxplot(data=Imerge, x='PotentialFraud',y='InscClaimAmtReimbursed')
#plt.ylim(6000,8000)
plt.title('Fraud by Distribution by Reimbursment Amount')
plt.xlabel('Potential Fraud')
plt.ylabel('Reinbursment')
#plt.legend()
# Out:
# Text(0, 0.5, 'Reinbursment')

# %%
# Fraud relationship to Reimbursement averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='InscClaimAmtReimbursed',  palette=['dodgerblue','tomato'], width=0.5, saturation=1)
#plt.ylim(6000,8000)
plt.title('Fraud by Claim Reimbursement Amount, Provider Averages')
plt.xlabel('Potential fraud')
plt.ylabel('Average claim reimbursement ($)')
#plt.legend()
# Out:
# Text(0, 0.5, 'Average claim reimbursement ($)')

# %%
# Fraud relationship to Reimbursement averaged by provider
sns.jointplot(data=Imerge_Pgroup, x='PotentialFraud',y='InscClaimAmtReimbursed',  palette=['dodgerblue','tomato'], hue='PotentialFraud')
#plt.ylim(6000,8000)
plt.title('Fraud by Claim Reimbursement Amount, Provider Averages')
plt.xlabel('Potential fraud')
plt.ylabel('Average claim reimbursement ($)')
#plt.legend()
# Out:
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Text(336.9714285714286, 0.5, 'Average claim reimbursement ($)')

# %% [markdown]
# ## State

# %%
# # Inpatient claims Groupby provider, average beneficiary state
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['State']].mean().reset_index()

# %%
plt.hist([Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']== 'Yes']['State'], Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']== 'No']['State']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=53)
plt.title('Fraud by Beneficiary State averaged by provider')
plt.xlabel('State averaged by provider')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Beneficiary State averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='State')
#plt.ylim(0,5)
plt.title('Fraud relationship to Beneficiary State averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Beneficiary Beneficiary State averaged by provider')
#plt.legend()
# Out:
# Text(0, 0.5, 'Beneficiary Beneficiary State averaged by provider')

# %% [markdown]
# ## Beneficiary Age

# %%
# Inpatient claims Groupby provider, average beneficiary age
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['Age']].mean().reset_index()

# %%
# Fraud relationship to Beneficiary Age

plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['Age'], Imerge[Imerge['PotentialFraud']== 'No']['Age']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=20)
plt.title('Fraud by Distribution of Beneficiary Ages')
plt.xlabel('Beneficiary Ages')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Beneficiary Age averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='Age')
#plt.ylim(0,5)
plt.title('Fraud relationship to Beneficiary Age averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Beneficiary Beneficiary Age averaged by provider')
#plt.legend()
# Out:
# Text(0, 0.5, 'Beneficiary Beneficiary Age averaged by provider')

# %% [markdown]
# ## Beneficiary Race

# %%
# Inpatient claims Groupby provider, average beneficiary race
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['Race']].mean().reset_index()
# 0 = UNKNOWN 1 = WHITE 2 = BLACK 3 = OTHER 4 = ASIAN 5 = HISPANIC 6 = NORTH AMERICAN NATIVE

# %%
# Fraud relationship to Beneficiary Race
plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['Race'], Imerge[Imerge['PotentialFraud']== 'No']['Race']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=4)
plt.title('Fraud by Distribution of Race')
plt.xlabel('Beneficiary Race')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Sex averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='Race')
#plt.ylim(0,5)
plt.title('Fraud relationship to Race averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Beneficiary Race averaged by provider')
#plt.legend()
# 0 = UNKNOWN 1 = WHITE 2 = BLACK 3 = OTHER 4 = ASIAN 5 = HISPANIC 6 = NORTH AMERICAN NATIVE
# Out:
# Text(0, 0.5, 'Beneficiary Race averaged by provider')

# %% [markdown]
# ## Beneficiary Sex

# %%
# Inpatient claims Groupby provider, average sex
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['Gender']].mean().reset_index()
# 1 = MALE 2 = FEMALE

# %%
# Fraud relationship to Beneficiary Sex
plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['Gender'], Imerge[Imerge['PotentialFraud']== 'No']['Gender']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=2)
plt.title('Fraud by Distribution of Sex')
plt.xlabel('Beneficiary Sex')
plt.ylabel('Count')
plt.legend()
# 1 = MALE 2 = FEMALE

# %%
# Fraud relationship to Sex averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='Gender')
#plt.ylim(0,5)
plt.title('Fraud relationship to Sex averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Beneficiary Sex averaged by provider')
#plt.legend()
# 1 = MALE 2 = FEMALE
# Out:
# Text(0, 0.5, 'Beneficiary Sex averaged by provider')

# %% [markdown]
# ## Number Chronic Conditions

# %%
# Inpatient claims Groupby provider, average number of chronic conditions
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['numChronic']].mean().reset_index()

# %%
# Fraud relationship to Beneficiary Number of Chronic Conditions
plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['numChronic'], Imerge[Imerge['PotentialFraud']== 'No']['numChronic']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=12)
plt.title('Fraud by Distribution of Number of Chronic Conditions')
plt.xlabel('Beneficiary Number of Chronic Conditions')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Number of Chronic Conditions averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='numChronic')
#plt.ylim(0,5)
plt.title('Fraud by Distribution of Number of Chronic Conditions averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Chronic Conditions')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Chronic Conditions')

# %% [markdown]
# ## Inpatient claims Groupby Provider, calculate mean for 'ClaimStartDt'

# %%
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['ClaimStartDt']].mean().reset_index()

# %% [markdown]
# ## Start Date of Claim

# %%
# Fraud relationship to Start date of claim averaged by provider
plt.hist([Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']== 'Yes']['ClaimStartDt'], 
          Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']== 'No']['ClaimStartDt']], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=60)
plt.title('Fraud by Distribution of Claim Start Dates averaged by provider')
plt.xlabel('Claim Start Date')
plt.ylabel('Count')
plt.legend()

# %% [markdown]
# ## Inpatient claims Groupby Provider, calculate mean for 'ClaimDuration', 'AdmitDays'

# %%
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['ClaimDuration','AdmitDays']].mean().reset_index()

# %% [markdown]
# ## Length of hospital stay

# %%
# Fraud relationship to Length of hospital stay
plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['AdmitDays'].dt.days, Imerge[Imerge['PotentialFraud']== 'No']['AdmitDays'].dt.days], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=35)
plt.title('Fraud by Distribution of Length of Inpatient Stay')
plt.xlabel('Days')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Length of hospital stay
sns.violinplot(data=Imerge, x='PotentialFraud',y='AdmitDays')
#plt.ylim(0,5)
plt.title('Fraud by Distribution of Length of Inpatient Stay')
plt.xlabel('Potential Fraud')
plt.ylabel('Days')
#plt.legend()
# Out:
# Text(0, 0.5, 'Days')

# %%
# Fraud relationship to Length of hospital stay averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='AdmitDays',  palette=['dodgerblue','tomato'], width=0.5, saturation=1)
#plt.ylim(0,5)
plt.title('Fraud by Length of Inpatient Stay, Provider Averages')
plt.xlabel('Potential Fraud')
plt.ylabel('Average admit days')
#plt.legend()
# Out:
# Text(0, 0.5, 'Average admit days')

# %%
# Fraud relationship to Reimbursement averaged by provider
sns.jointplot(data=Imerge_Pgroup, x='PotentialFraud',y='AdmitDays',  palette=['dodgerblue','tomato'], hue='PotentialFraud')
#plt.ylim(6000,8000)

#plt.legend()
# Out:
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/RK/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Length of claim

# %%
# Fraud relationship to Duration of Claim
plt.hist([Imerge[Imerge['PotentialFraud']== 'Yes']['ClaimDuration'].dt.days, Imerge[Imerge['PotentialFraud']== 'No']['ClaimDuration'].dt.days], 
         color=['r', 'skyblue'], label=['Potential Fraud','Not Fraud'], bins=35)
plt.title('Fraud by Distribution of Claim Duraton')
plt.xlabel('Days')
plt.ylabel('Count')
plt.legend()

# %%
# Fraud relationship to Duration of Claim
sns.boxplot(data=Imerge, x='PotentialFraud',y='ClaimDuration')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Claim Duration')
plt.xlabel('Potential Fraud')
plt.ylabel('Days')
#plt.legend()
# Out:
# Text(0, 0.5, 'Days')

# %%
# Fraud relationship to Duration of Claim averaged by provider
sns.violinplot(data=Imerge_Pgroup, x='PotentialFraud',y='ClaimDuration')
#plt.ylim(0,5)
plt.title('Fraud by Distribution of Claim Duration averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Days')
#plt.legend()
# Out:
# Text(0, 0.5, 'Days')

# %%
Imerge[Imerge['PotentialFraud']== 'Yes']['ClaimDuration'].dt.days.values
# Out:
# array([6, 7, 6, ..., 2, 4, 4])

# %% [markdown]
# ## Number of Diagnostic Codes

# %%
# Inpatient claims Groupby provider, average number of codes
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['numDiagCodes', 'numProcCodes']].mean().reset_index()

# %%
# Fraud relationship to Number of Diagnostic Codes
sns.boxplot(data=Imerge, x='PotentialFraud',y='numDiagCodes')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Diagnostic Codes')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Diagnostic Codes')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Diagnostic Codes')

# %%
# Fraud relationship to Number of Diagnostic Codes averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='numDiagCodes')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Diagnostic Codes averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Diagnostic Codes averaged by provider')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Diagnostic Codes averaged by provider')

# %% [markdown]
# ## Number of Procedure Codes

# %%
# Fraud relationship to Number of Procedure Codes
sns.boxplot(data=Imerge, x='PotentialFraud',y='numProcCodes')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Procedure Codes')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Procedure Codes')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Procedure Codes')

# %%
# Fraud relationship to Number of Diagnostic Codes averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='numProcCodes')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Procedure Codes averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Procedure Codes averaged by provider')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Procedure Codes averaged by provider')

# %% [markdown]
# ## Number of Physicians

# %%
# Inpatient claims Groupby provider, average number of Physicians
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['numPhysicians']].mean().reset_index()

# %%
# Fraud relationship to Number of Physicians
sns.boxplot(data=Imerge, x='PotentialFraud',y='numPhysicians')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Physicians')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Physicians')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Physicians')

# %%
Imerge_Pgroup.groupby(['PotentialFraud'])[['numPhysicians']].std().reset_index()
# Out:
#   PotentialFraud  numPhysicians
# 0             No       0.360602
# 1            Yes       0.186009

# %%
Imerge_Pgroup.groupby(['PotentialFraud'])[['numPhysicians']].mad().reset_index()
# Out:
#   PotentialFraud  numPhysicians
# 0             No       0.261387
# 1            Yes       0.137609

# %%
Imerge_Pgroup.groupby(['PotentialFraud'])[['numPhysicians']].skew().reset_index()
# Out:
#   PotentialFraud  numPhysicians
# 0             No       0.200102
# 1            Yes       0.996130

# %%
Imerge_Pgroup.groupby(['PotentialFraud'])[['numPhysicians']].apply(pd.DataFrame.kurt).reset_index()
# Out:
#   PotentialFraud  numPhysicians
# 0             No       2.354072
# 1            Yes       6.194360

# %%
# Fraud relationship to Number of Physicians averaged by provider
sns.boxplot(data=Imerge_Pgroup, x='PotentialFraud',y='numPhysicians')
#plt.ylim(0,10)
plt.title('Fraud by Distribution of Number of Physicians averaged by provider')
plt.xlabel('Potential Fraud')
plt.ylabel('Number of Physicians averaged by provider')
#plt.legend()
# Out:
# Text(0, 0.5, 'Number of Physicians averaged by provider')

# %% [markdown]
# ## Number of Beneficiaries

# %%
Imerge_Pgroup=Imerge.groupby(['PotentialFraud'])[['BeneID']].describe().reset_index()

# %%
Imerge_Pgroup
# Potentially fradulent providers are more likely to be larger/serve more beneficiaries
# Out:
#   PotentialFraud BeneID
#                   count unique         top freq
# 0             No  17072  14602  BENE120987    6
# 1            Yes  23402  19284  BENE134170    7

# %% [markdown]
# # Describe statistics of Potentially fradulent Yes or No

# %%
Imerge[Imerge['PotentialFraud']=='No'].describe(include='all')
# Out:
#         Provider PotentialFraud      BeneID  ClaimStartDt    ClaimEndDt  \
# count      17072          17072       17072  17072.000000  17072.000000
# unique      1652              1       14602           NaN           NaN
# top     PRV55916             No  BENE120987           NaN           NaN
# freq         115          17072           6           NaN           NaN
# mean         NaN            NaN         NaN    176.898196    176.556408
# std          NaN            NaN         NaN    105.013991    104.571045
# min          NaN            NaN         NaN      1.000000      1.000000
# 25%          NaN            NaN         NaN     87.000000     86.000000
# 50%          NaN            NaN         NaN    172.000000    172.000000
# 75%          NaN            NaN         NaN    267.000000    266.000000
# max          NaN            NaN         NaN    366.000000    365.000000
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# ...

# %%
Imerge[Imerge['PotentialFraud']=='Yes'].describe(include='all')
# Out:
#         Provider PotentialFraud      BeneID  ClaimStartDt    ClaimEndDt  \
# count      23402          23402       23402  23402.000000  23402.000000
# unique       440              1       19284           NaN           NaN
# top     PRV52019            Yes  BENE134170           NaN           NaN
# freq         516          23402           7           NaN           NaN
# mean         NaN            NaN         NaN    176.977566    176.287540
# std          NaN            NaN         NaN    105.206422    104.724061
# min          NaN            NaN         NaN      1.000000      1.000000
# 25%          NaN            NaN         NaN     85.000000     84.000000
# 50%          NaN            NaN         NaN    174.000000    174.000000
# 75%          NaN            NaN         NaN    267.000000    265.000000
# max          NaN            NaN         NaN    366.000000    365.000000
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# ...

# %%
# by provider groupby
Imerge[Imerge['PotentialFraud']=='No'].groupby('Provider').size()
#.describe(include='all').reset_index()
# Out:
# Provider
# PRV51001     5
# PRV51007     3
# PRV51008     2
# PRV51011     1
# PRV51023     9
#             ..
# PRV57719     4
# PRV57728     1
# PRV57729    11
# PRV57732    11
# PRV57757    11
# Length: 1652, dtype: int64

# %%
# by provider groupby

# %% [markdown]
# # Are there more potential fraud providers in Inpatient or Outpatient claims?

# %%
# three way merge of Inpatient claims, drop uneeded columns and 'ClmProcedureCode_6' which is empty
Omerge = trF.merge(trO.merge(trB, on='BeneID'), on='Provider').drop(['index','index_x','index_y', 'DOB', 'ClaimID'], axis=1)

# %%
fraud=trF[trF['PotentialFraud']=='Yes']

# %%
fraud
# Out:
#       index  Provider PotentialFraud
# 1         1  PRV51003            Yes
# 3         3  PRV51005            Yes
# 13       13  PRV51021            Yes
# 25       25  PRV51037            Yes
# 37       37  PRV51052            Yes
# ...     ...       ...            ...
# 5307   5307  PRV57642            Yes
# 5324   5324  PRV57667            Yes
# 5329   5329  PRV57672            Yes
# 5351   5351  PRV57697            Yes
# 5360   5360  PRV57709            Yes
#
# [506 rows x 3 columns]

# %%
# Num of unique fradulent providers in Inpatient claims = 440
len(Imerge.loc[np.where(Imerge['Provider'].isin(fraud['Provider']))]['Provider'].unique())
# Out:
# 440

# %%
Omerge.groupby(['Provider']).size()
# Out:
# Provider
# PRV51001      20
# PRV51003      70
# PRV51004     149
# PRV51005    1165
# PRV51007      69
#             ...
# PRV57759      28
# PRV57760      22
# PRV57761      82
# PRV57762       1
# PRV57763     118
# Length: 5012, dtype: int64

# %%
# Num of unique fradulent providers in Outpatient claims = 462
len(Omerge.loc[np.where(Omerge['Provider'].isin(fraud['Provider']))]['Provider'].unique())
# Out:
# 462

# %%
Imerge.groupby(['Provider','PotentialFraud'])['ClaimDuration','AdmitDays'].mean().reset_index()
# Out:
# <ipython-input-424-59096f0f7da0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Imerge.groupby(['Provider','PotentialFraud'])['ClaimDuration','AdmitDays'].mean().reset_index()
#       Provider PotentialFraud  ClaimDuration  AdmitDays
# 0     PRV51001             No       5.000000   5.000000
# 1     PRV51003            Yes       5.161290   5.161290
# 2     PRV51007             No       5.333333   5.333333
# 3     PRV51008             No       4.000000   4.000000
# 4     PRV51011             No       5.000000   5.000000
# ...        ...            ...            ...        ...
# 2087  PRV57719             No      13.750000  13.750000
# 2088  PRV57728             No       4.000000   4.000000
# 2089  PRV57729             No       5.545455   5.545455
# 2090  PRV57732             No       5.272727   5.272727
# 2091  PRV57757             No       6.272727   6.272727
#
# [2092 rows x 4 columns]

# %% [markdown]
# # Levene test for equal variances and T-test for means

# %%
Imerge_Pgroup= Imerge.groupby(['Provider','PotentialFraud'])[['ClaimDuration','AdmitDays', 'InscClaimAmtReimbursed']].mean().reset_index()

# %%
# test for equal variances'InscClaimAmtReimbursed'
# The Levene test tests the null hypothesis that all input samples are from populations with equal variances.

# %%
# ‘median’ : Recommended for skewed (non-normal) distributions>
scipy.stats.levene(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['InscClaimAmtReimbursed'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['InscClaimAmtReimbursed'], center='median')
# Out:
# LeveneResult(statistic=33.731231116892054, pvalue=7.297212811522808e-09)

# %%
# ‘mean’ : Recommended for symmetric, moderate-tailed distributions.
scipy.stats.levene(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['InscClaimAmtReimbursed'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['InscClaimAmtReimbursed'], center='mean')
# Out:
# LeveneResult(statistic=38.30605163875601, pvalue=7.257456079309012e-10)

# %%
# ‘trimmed’ : Recommended for heavy-tailed distributions
scipy.stats.levene(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['InscClaimAmtReimbursed'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['InscClaimAmtReimbursed'], center='trimmed')
# Out:
# LeveneResult(statistic=93.76115604247582, pvalue=1.1294557698274072e-21)

# %%
# The small p-value suggests that the populations do not have equal variances.
# This is not surprising, given the sample variances:

# %%
np.var(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['InscClaimAmtReimbursed'],ddof=1)
# Out:
# 30045300.45940232

# %%
np.var(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['InscClaimAmtReimbursed'],ddof=1)
# Out:
# 11905307.318503082

# %%
# test for equal variances'AdmitDays'
# The Levene test tests the null hypothesis that all input samples are from populations with equal variances.

# %%
# ‘median’ : Recommended for skewed (non-normal) distributions>
scipy.stats.levene(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['AdmitDays'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['AdmitDays'], center='median')
# Out:
# LeveneResult(statistic=54.91963197925211, pvalue=1.813156914694333e-13)

# %%
# The small p-value suggests that the populations do not have equal variances.
# This is not surprising, given the sample variances:

# %%
np.var(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['AdmitDays'],ddof=1)
# Out:
# 8.900237662276906

# %%
np.var(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['AdmitDays'],ddof=1)
# Out:
# 2.5734013838723557

# %% [markdown]
# ## T test for equal means 'InscClaimAmtReimbursed' and 'AdmitDays'

# %%
statsmodels.stats.weightstats.ttest_ind(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['InscClaimAmtReimbursed'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['InscClaimAmtReimbursed'])
# Out:
# (-3.8626122175180555, 0.00011559517791814175, 2090.0)

# %%
statsmodels.stats.weightstats.ttest_ind(Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==0]['AdmitDays'], 
                   Imerge_Pgroup[Imerge_Pgroup['PotentialFraud']==1]['AdmitDays'])
# Out:
# (-3.84453334886447, 0.00012439275835561309, 2090.0)
